# %% [markdown]
# ## Step 1: Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib import pyplot
import time
import os
import torch
import torchvision
from torch.utils.data import random_split
import torchvision.models as models
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# %% [markdown]
# ## Step 2: Loading dataset

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# !unzip /content/gdrive/MyDrive/Dataset3.zip
data_dir = "/content/dataset5/B/";
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset5/E/u/color_20_0231.png
#   inflating: dataset5/E/u/color_20_0232.png
#   inflating: dataset5/E/u/color_20_0233.png
#   inflating: dataset5/E/u/color_20_0234.png
#   inflating: dataset5/E/u/color_20_0235.png
#   inflating: dataset5/E/u/color_20_0236.png
#   inflating: dataset5/E/u/color_20_0237.png
#   inflating: dataset5/E/u/color_20_0238.png
#   inflating: dataset5/E/u/color_20_0239.png
#   inflating: dataset5/E/u/color_20_0240.png
#   inflating: dataset5/E/u/color_20_0241.png
#   inflating: dataset5/E/u/color_20_0242.png
#   inflating: dataset5/E/u/color_20_0243.png
#   inflating: dataset5/E/u/color_20_0244.png
#   inflating: dataset5/E/u/color_20_0245.png
#   inflating: dataset5/E/u/color_20_0246.png
#   inflating: dataset5/E/u/color_20_0247.png
#   inflating: dataset5/E/u/color_20_0248.png
#   inflating: dataset5/E/u/color_20_0249.png
#   inflating: dataset5/E/u/color_20_0250.png
#   inflating: dataset5/E/u/color_20_0251.png
#   inflating: dataset5/E/u/color_20_0252.png
#   inflating: dataset5/E/u/color_20_0253.png
#   inflating: dataset5/E/u/color_20_0254.png
#   inflating: dataset5/E/u/color_20_0255.png
#   inflating: dataset5/E/u/color_20_0256.png
#   inflating: dataset5/E/u/color_20_0257.png
#   inflating: dataset5/E/u/color_20_0258.png
#   inflating: dataset5/E/u/color_20_0259.png
#   inflating: dataset5/E/u/color_20_0260.png
#   inflating: dataset5/E/u/color_20_0261.png
#   inflating: dataset5/E/u/color_20_0262.png
#   inflating: dataset5/E/u/color_20_0263.png
#   inflating: dataset5/E/u/color_20_0264.png
#   inflating: dataset5/E/u/color_20_0265.png
#   inflating: dataset5/E/u/color_20_0266.png
#   inflating: dataset5/E/u/color_20_0267.png
#   inflating: dataset5/E/u/color_20_0268.png
#   inflating: dataset5/E/u/color_20_0269.png
#   inflating: dataset5/E/u/color_20_0270.png
#   inflating: dataset5/E/u/color_20_0271.png
#   inflating: dataset5/E/u/color_20_0272.png
#   inflating: dataset5/E/u/color_20_0273.png
#   inflating: dataset5/E/u/color_20_0274.png
#   inflating: dataset5/E/u/color_20_0275.png
#   inflating: dataset5/E/u/color_20_0276.png
#   inflating: dataset5/E/u/color_20_0277.png
#   inflating: dataset5/E/u/color_20_0278.png
#   inflating: dataset5/E/u/color_20_0279.png
#   inflating: dataset5/E/u/color_20_0280.png
#   inflating: dataset5/E/u/color_20_0281.png
#   inflating: dataset5/E/u/color_20_0282.png
#   inflating: dataset5/E/u/color_20_0283.png
#   inflating: dataset5/E/u/color_20_0284.png
#   inflating: dataset5/E/u/color_20_0285.png
#   inflating: dataset5/E/u/color_20_0286.png
#   inflating: dataset5/E/u/color_20_0287.png
#   inflating: dataset5/E/u/color_20_0288.png
#   inflating: dataset5/E/u/color_20_0289.png
#   inflating: dataset5/E/u/color_20_0290.png
#   inflating: dataset5/E/u/color_20_0291.png
#   inflating: dataset5/E/u/color_20_0292.png
#   inflating: dataset5/E/u/color_20_0293.png
#   inflating: dataset5/E/u/color_20_0294.png
#   inflating: dataset5/E/u/color_20_0295.png
#   inflating: dataset5/E/u/color_20_0296.png
#   inflating: dataset5/E/u/color_20_0297.png
#   inflating: dataset5/E/u/color_20_0298.png
#   inflating: dataset5/E/u/color_20_0299.png
#   inflating: dataset5/E/u/color_20_0300.png
#   inflating: dataset5/E/u/color_20_0301.png
#   inflating: dataset5/E/u/color_20_0302.png
#   inflating: dataset5/E/u/color_20_0303.png
#   inflating: dataset5/E/u/color_20_0304.png
#   inflating: dataset5/E/u/color_20_0305.png
#   inflating: dataset5/E/u/color_20_0306.png
#   inflating: dataset5/E/u/color_20_0307.png
#   inflating: dataset5/E/u/color_20_0308.png
#   inflating: dataset5/E/u/color_20_0309.png
#   inflating: dataset5/E/u/color_20_0310.png
#   inflating: dataset5/E/u/color_20_0311.png
#   inflating: dataset5/E/u/color_20_0312.png
#   inflating: dataset5/E/u/color_20_0313.png
#   inflating: dataset5/E/u/color_20_0314.png
#   inflating: dataset5/E/u/color_20_0315.png
#   inflating: dataset5/E/u/color_20_0316.png
#   inflating: dataset5/E/u/color_20_0317.png
#   inflating: dataset5/E/u/color_20_0318.png
#   inflating: dataset5/E/u/color_20_0319.png
#   inflating: dataset5/E/u/color_20_0320.png
#   inflating: dataset5/E/u/color_20_0321.png
#   inflating: dataset5/E/u/color_20_0322.png
#   inflating: dataset5/E/u/color_20_0323.png
#   inflating: dataset5/E/u/color_20_0324.png
#   inflating: dataset5/E/u/color_20_0325.png
#   inflating: dataset5/E/u/color_20_0326.png
#   inflating: dataset5/E/u/color_20_0327.png
#   inflating: dataset5/E/u/color_20_0328.png
#   inflating: dataset5/E/u/color_20_0329.png
#   inflating: dataset5/E/u/color_20_0330.png
#   inflating: dataset5/E/u/color_20_0331.png
#   inflating: dataset5/E/u/color_20_0332.png
#   inflating: dataset5/E/u/color_20_0333.png
#   inflating: dataset5/E/u/color_20_0334.png
#   inflating: dataset5/E/u/color_20_0335.png
#   inflating: dataset5/E/u/color_20_0336.png
#   inflating: dataset5/E/u/color_20_0337.png
#   inflating: dataset5/E/u/color_20_0338.png
#   inflating: dataset5/E/u/color_20_0339.png
#   inflating: dataset5/E/u/color_20_0340.png
#   inflating: dataset5/E/u/color_20_0341.png
#   inflating: dataset5/E/u/color_20_0342.png
#   inflating: dataset5/E/u/color_20_0343.png
#   inflating: dataset5/E/u/color_20_0344.png
#   inflating: dataset5/E/u/color_20_0345.png
#   inflating: dataset5/E/u/color_20_0346.png
#   inflating: dataset5/E/u/color_20_0347.png
#   inflating: dataset5/E/u/color_20_0348.png
#   inflating: dataset5/E/u/color_20_0349.png
#   inflating: dataset5/E/u/color_20_0350.png
#   inflating: dataset5/E/u/color_20_0351.png
#   inflating: dataset5/E/u/color_20_0352.png
#   inflating: dataset5/E/u/color_20_0353.png
#   inflating: dataset5/E/u/color_20_0354.png
#   inflating: dataset5/E/u/color_20_0355.png
#   inflating: dataset5/E/u/color_20_0356.png
#   inflating: dataset5/E/u/color_20_0357.png
#   inflating: dataset5/E/u/color_20_0358.png
#   inflating: dataset5/E/u/color_20_0359.png
#   inflating: dataset5/E/u/color_20_0360.png
#   inflating: dataset5/E/u/color_20_0361.png
#   inflating: dataset5/E/u/color_20_0362.png
#   inflating: dataset5/E/u/color_20_0363.png
#   inflating: dataset5/E/u/color_20_0364.png
#   inflating: dataset5/E/u/color_20_0365.png
#   inflating: dataset5/E/u/color_20_0366.png
#   inflating: dataset5/E/u/color_20_0367.png
#   inflating: dataset5/E/u/color_20_0368.png
#   inflating: dataset5/E/u/color_20_0369.png
#   inflating: dataset5/E/u/color_20_0370.png
#   inflating: dataset5/E/u/color_20_0371.png
#   inflating: dataset5/E/u/color_20_0372.png
#   inflating: dataset5/E/u/color_20_0373.png
#   inflating: dataset5/E/u/color_20_0374.png
#   inflating: dataset5/E/u/color_20_0375.png
#   inflating: dataset5/E/u/color_20_0376.png
#   inflating: dataset5/E/u/color_20_0377.png
#   inflating: dataset5/E/u/color_20_0378.png
#   inflating: dataset5/E/u/color_20_0379.png
#   inflating: dataset5/E/u/color_20_0380.png
#   inflating: dataset5/E/u/color_20_0381.png
#   inflating: dataset5/E/u/color_20_0382.png
#   inflating: dataset5/E/u/color_20_0383.png
#   inflating: dataset5/E/u/color_20_0384.png
#   inflating: dataset5/E/u/color_20_0385.png
#   inflating: dataset5/E/u/color_20_0386.png
#   inflating: dataset5/E/u/color_20_0387.png
#   inflating: dataset5/E/u/color_20_0388.png
#   inflating: dataset5/E/u/color_20_0389.png
#   inflating: dataset5/E/u/color_20_0390.png
#   inflating: dataset5/E/u/color_20_0391.png
#   inflating: dataset5/E/u/color_20_0392.png
#   inflating: dataset5/E/u/color_20_0393.png
#   inflating: dataset5/E/u/color_20_0394.png
#   inflating: dataset5/E/u/color_20_0395.png
#   inflating: dataset5/E/u/color_20_0396.png
#   inflating: dataset5/E/u/color_20_0397.png
#   inflating: dataset5/E/u/color_20_0398.png
#   inflating: dataset5/E/u/color_20_0399.png
#   inflating: dataset5/E/u/color_20_0400.png
#   inflating: dataset5/E/u/color_20_0401.png
#   inflating: dataset5/E/u/color_20_0402.png
#   inflating: dataset5/E/u/color_20_0403.png
#   inflating: dataset5/E/u/color_20_0404.png
#   inflating: dataset5/E/u/color_20_0405.png
#   inflating: dataset5/E/u/color_20_0406.png
#   inflating: dataset5/E/u/color_20_0407.png
#   inflating: dataset5/E/u/color_20_0408.png
#   inflating: dataset5/E/u/color_20_0409.png
#   inflating: dataset5/E/u/color_20_0410.png
#   inflating: dataset5/E/u/color_20_0411.png
#   inflating: dataset5/E/u/color_20_0412.png
#   inflating: dataset5/E/u/color_20_0413.png
#   inflating: dataset5/E/u/color_20_0414.png
#   inflating: dataset5/E/u/color_20_0415.png
#   inflating: dataset5/E/u/color_20_0416.png
#   inflating: dataset5/E/u/color_20_0417.png
#   inflating: dataset5/E/u/color_20_0418.png
#   inflating: dataset5/E/u/color_20_0419.png
#   inflating: dataset5/E/u/color_20_0420.png
#   inflating: dataset5/E/u/color_20_0421.png
#   inflating: dataset5/E/u/color_20_0422.png
#   inflating: dataset5/E/u/color_20_0423.png
#   inflating: dataset5/E/u/color_20_0424.png
#   inflating: dataset5/E/u/color_20_0425.png
#   inflating: dataset5/E/u/color_20_0426.png
#   inflating: dataset5/E/u/color_20_0427.png
#   inflating: dataset5/E/u/color_20_0428.png
#   inflating: dataset5/E/u/color_20_0429.png
#   inflating: dataset5/E/u/color_20_0430.png
#   inflating: dataset5/E/u/color_20_0431.png
#   inflating: dataset5/E/u/color_20_0432.png
#   inflating: dataset5/E/u/color_20_0433.png
#   inflating: dataset5/E/u/color_20_0434.png
#   inflating: dataset5/E/u/color_20_0435.png
#   inflating: dataset5/E/u/color_20_0436.png
#   inflating: dataset5/E/u/color_20_0437.png
#   inflating: dataset5/E/u/color_20_0438.png
#   inflating: dataset5/E/u/color_20_0439.png
#   inflating: dataset5/E/u/color_20_0440.png
#   inflating: dataset5/E/u/color_20_0441.png
#   inflating: dataset5/E/u/color_20_0442.png
#   inflating: dataset5/E/u/color_20_0443.png
#   inflating: dataset5/E/u/color_20_0444.png
#   inflating: dataset5/E/u/color_20_0445.png
#   inflating: dataset5/E/u/color_20_0446.png
#   inflating: dataset5/E/u/color_20_0447.png
#   inflating: dataset5/E/u/color_20_0448.png
#   inflating: dataset5/E/u/color_20_0449.png
#   inflating: dataset5/E/u/color_20_0450.png
#   inflating: dataset5/E/u/color_20_0451.png
#   inflating: dataset5/E/u/color_20_0452.png
#   inflating: dataset5/E/u/color_20_0453.png
#   inflating: dataset5/E/u/color_20_0454.png
#   inflating: dataset5/E/u/color_20_0455.png
#   inflating: dataset5/E/u/color_20_0456.png
#   inflating: dataset5/E/u/color_20_0457.png
#   inflating: dataset5/E/u/color_20_0458.png
#   inflating: dataset5/E/u/color_20_0459.png
#   inflating: dataset5/E/u/color_20_0460.png
#   inflating: dataset5/E/u/color_20_0461.png
#   inflating: dataset5/E/u/color_20_0462.png
#   inflating: dataset5/E/u/color_20_0463.png
#   inflating: dataset5/E/u/color_20_0464.png
#   inflating: dataset5/E/u/color_20_0465.png
#   inflating: dataset5/E/u/color_20_0466.png
#   inflating: dataset5/E/u/color_20_0467.png
#   inflating: dataset5/E/u/color_20_0468.png
#   inflating: dataset5/E/u/color_20_0469.png
#   inflating: dataset5/E/u/color_20_0470.png
#   inflating: dataset5/E/u/color_20_0471.png
#   inflating: dataset5/E/u/color_20_0472.png
#   inflating: dataset5/E/u/color_20_0473.png
#   inflating: dataset5/E/u/color_20_0474.png
#   inflating: dataset5/E/u/color_20_0475.png
#   inflating: dataset5/E/u/color_20_0476.png
#   inflating: dataset5/E/u/color_20_0477.png
#   inflating: dataset5/E/u/color_20_0478.png
#   inflating: dataset5/E/u/color_20_0479.png
#   inflating: dataset5/E/u/color_20_0480.png
#   inflating: dataset5/E/u/color_20_0481.png
#   inflating: dataset5/E/u/color_20_0482.png
#   inflating: dataset5/E/u/color_20_0483.png
#   inflating: dataset5/E/u/color_20_0484.png
#   inflating: dataset5/E/u/color_20_0485.png
#   inflating: dataset5/E/u/color_20_0486.png
#   inflating: dataset5/E/u/color_20_0487.png
#   inflating: dataset5/E/u/color_20_0488.png
#   inflating: dataset5/E/u/color_20_0489.png
#   inflating: dataset5/E/u/color_20_0490.png
#   inflating: dataset5/E/u/color_20_0491.png
#   inflating: dataset5/E/u/color_20_0492.png
#   inflating: dataset5/E/u/color_20_0493.png
#   inflating: dataset5/E/u/color_20_0494.png
#   inflating: dataset5/E/u/color_20_0495.png
#   inflating: dataset5/E/u/color_20_0496.png
#   inflating: dataset5/E/u/color_20_0497.png
#   inflating: dataset5/E/u/color_20_0498.png
#   inflating: dataset5/E/u/color_20_0499.png
#   inflating: dataset5/E/u/color_20_0500.png
#   inflating: dataset5/E/u/color_20_0501.png
#   inflating: dataset5/E/u/color_20_0502.png
#   inflating: dataset5/E/u/color_20_0503.png
#   inflating: dataset5/E/u/color_20_0504.png
#   inflating: dataset5/E/u/color_20_0505.png
#   inflating: dataset5/E/u/color_20_0506.png
#   inflating: dataset5/E/u/color_20_0507.png
#   inflating: dataset5/E/u/color_20_0508.png
#   inflating: dataset5/E/u/color_20_0509.png
#   inflating: dataset5/E/u/color_20_0510.png
#   inflating: dataset5/E/u/color_20_0511.png
#   inflating: dataset5/E/u/color_20_0512.png
#   inflating: dataset5/E/u/color_20_0513.png
#   inflating: dataset5/E/u/color_20_0514.png
#   inflating: dataset5/E/u/color_20_0515.png
#   inflating: dataset5/E/u/color_20_0516.png
#   inflating: dataset5/E/u/color_20_0517.png
#   inflating: dataset5/E/u/color_20_0518.png
#   inflating: dataset5/E/u/color_20_0519.png
#   inflating: dataset5/E/u/color_20_0520.png
#   inflating: dataset5/E/u/color_20_0521.png
#   inflating: dataset5/E/u/color_20_0522.png
#   inflating: dataset5/E/u/color_20_0523.png
#   inflating: dataset5/E/u/color_20_0524.png
#   inflating: dataset5/E/u/color_20_0525.png
#   inflating: dataset5/E/u/color_20_0526.png
#   inflating: dataset5/E/u/color_20_0527.png
#   inflating: dataset5/E/u/color_20_0528.png
#   inflating: dataset5/E/u/color_20_0529.png
#   inflating: dataset5/E/u/color_20_0530.png
#   inflating: dataset5/E/u/depth_20_0001.png
#   inflating: dataset5/E/u/depth_20_0002.png
#   inflating: dataset5/E/u/depth_20_0003.png
#   inflating: dataset5/E/u/depth_20_0004.png
#   inflating: dataset5/E/u/depth_20_0005.png
#   inflating: dataset5/E/u/depth_20_0006.png
#   inflating: dataset5/E/u/depth_20_0007.png
#   inflating: dataset5/E/u/depth_20_0008.png
#   inflating: dataset5/E/u/depth_20_0009.png
#   inflating: dataset5/E/u/depth_20_0010.png
#   inflating: dataset5/E/u/depth_20_0011.png
#   inflating: dataset5/E/u/depth_20_0012.png
#   inflating: dataset5/E/u/depth_20_0013.png
#   inflating: dataset5/E/u/depth_20_0014.png
#   inflating: dataset5/E/u/depth_20_0015.png
#   inflating: dataset5/E/u/depth_20_0016.png
#   inflating: dataset5/E/u/depth_20_0017.png
#   inflating: dataset5/E/u/depth_20_0018.png
#   inflating: dataset5/E/u/depth_20_0019.png
#   inflating: dataset5/E/u/depth_20_0020.png
#   inflating: dataset5/E/u/depth_20_0021.png
#   inflating: dataset5/E/u/depth_20_0022.png
#   inflating: dataset5/E/u/depth_20_0023.png
#   inflating: dataset5/E/u/depth_20_0024.png
#   inflating: dataset5/E/u/depth_20_0025.png
#   inflating: dataset5/E/u/depth_20_0026.png
#   inflating: dataset5/E/u/depth_20_0027.png
#   inflating: dataset5/E/u/depth_20_0028.png
#   inflating: dataset5/E/u/depth_20_0029.png
#   inflating: dataset5/E/u/depth_20_0030.png
#   inflating: dataset5/E/u/depth_20_0031.png
#   inflating: dataset5/E/u/depth_20_0032.png
#   inflating: dataset5/E/u/depth_20_0033.png
#   inflating: dataset5/E/u/depth_20_0034.png
#   inflating: dataset5/E/u/depth_20_0035.png
#   inflating: dataset5/E/u/depth_20_0036.png
#   inflating: dataset5/E/u/depth_20_0037.png
#   inflating: dataset5/E/u/depth_20_0038.png
#   inflating: dataset5/E/u/depth_20_0039.png
#   inflating: dataset5/E/u/depth_20_0040.png
#   inflating: dataset5/E/u/depth_20_0041.png
#   inflating: dataset5/E/u/depth_20_0042.png
#   inflating: dataset5/E/u/depth_20_0043.png
#   inflating: dataset5/E/u/depth_20_0044.png
#   inflating: dataset5/E/u/depth_20_0045.png
#   inflating: dataset5/E/u/depth_20_0046.png
#   inflating: dataset5/E/u/depth_20_0047.png
#   inflating: dataset5/E/u/depth_20_0048.png
#   inflating: dataset5/E/u/depth_20_0049.png
#   inflating: dataset5/E/u/depth_20_0050.png
#   inflating: dataset5/E/u/depth_20_0051.png
#   inflating: dataset5/E/u/depth_20_0052.png
#   inflating: dataset5/E/u/depth_20_0053.png
#   inflating: dataset5/E/u/depth_20_0054.png
#   inflating: dataset5/E/u/depth_20_0055.png
#   inflating: dataset5/E/u/depth_20_0056.png
#   inflating: dataset5/E/u/depth_20_0057.png
#   inflating: dataset5/E/u/depth_20_0058.png
#   inflating: dataset5/E/u/depth_20_0059.png
#   inflating: dataset5/E/u/depth_20_0060.png
#   inflating: dataset5/E/u/depth_20_0061.png
#   inflating: dataset5/E/u/depth_20_0062.png
#   inflating: dataset5/E/u/depth_20_0063.png
#   inflating: dataset5/E/u/depth_20_0064.png
#   inflating: dataset5/E/u/depth_20_0065.png
#   inflating: dataset5/E/u/depth_20_0066.png
#   inflating: dataset5/E/u/depth_20_0067.png
#   inflating: dataset5/E/u/depth_20_0068.png
#   inflating: dataset5/E/u/depth_20_0069.png
#   inflating: dataset5/E/u/depth_20_0070.png
#   inflating: dataset5/E/u/depth_20_0071.png
#   inflating: dataset5/E/u/depth_20_0072.png
#   inflating: dataset5/E/u/depth_20_0073.png
#   inflating: dataset5/E/u/depth_20_0074.png
#   inflating: dataset5/E/u/depth_20_0075.png
#   inflating: dataset5/E/u/depth_20_0076.png
#   inflating: dataset5/E/u/depth_20_0077.png
#   inflating: dataset5/E/u/depth_20_0078.png
#   inflating: dataset5/E/u/depth_20_0079.png
#   inflating: dataset5/E/u/depth_20_0080.png
#   inflating: dataset5/E/u/depth_20_0081.png
#   inflating: dataset5/E/u/depth_20_0082.png
#   inflating: dataset5/E/u/depth_20_0083.png
#   inflating: dataset5/E/u/depth_20_0084.png
#   inflating: dataset5/E/u/depth_20_0085.png
#   inflating: dataset5/E/u/depth_20_0086.png
#   inflating: dataset5/E/u/depth_20_0087.png
#   inflating: dataset5/E/u/depth_20_0088.png
#   inflating: dataset5/E/u/depth_20_0089.png
#   inflating: dataset5/E/u/depth_20_0090.png
#   inflating: dataset5/E/u/depth_20_0091.png
#   inflating: dataset5/E/u/depth_20_0092.png
#   inflating: dataset5/E/u/depth_20_0093.png
#   inflating: dataset5/E/u/depth_20_0094.png
#   inflating: dataset5/E/u/depth_20_0095.png
#   inflating: dataset5/E/u/depth_20_0096.png
#   inflating: dataset5/E/u/depth_20_0097.png
#   inflating: dataset5/E/u/depth_20_0098.png
#   inflating: dataset5/E/u/depth_20_0099.png
#   inflating: dataset5/E/u/depth_20_0100.png
#   inflating: dataset5/E/u/depth_20_0101.png
#   inflating: dataset5/E/u/depth_20_0102.png
#   inflating: dataset5/E/u/depth_20_0103.png
#   inflating: dataset5/E/u/depth_20_0104.png
#   inflating: dataset5/E/u/depth_20_0105.png
#   inflating: dataset5/E/u/depth_20_0106.png
#   inflating: dataset5/E/u/depth_20_0107.png
#   inflating: dataset5/E/u/depth_20_0108.png
#   inflating: dataset5/E/u/depth_20_0109.png
#   inflating: dataset5/E/u/depth_20_0110.png
#   inflating: dataset5/E/u/depth_20_0111.png
#   inflating: dataset5/E/u/depth_20_0112.png
#   inflating: dataset5/E/u/depth_20_0113.png
#   inflating: dataset5/E/u/depth_20_0114.png
#   inflating: dataset5/E/u/depth_20_0115.png
#   inflating: dataset5/E/u/depth_20_0116.png
#   inflating: dataset5/E/u/depth_20_0117.png
#   inflating: dataset5/E/u/depth_20_0118.png
#   inflating: dataset5/E/u/depth_20_0119.png
#   inflating: dataset5/E/u/depth_20_0120.png
#   inflating: dataset5/E/u/depth_20_0121.png
#   inflating: dataset5/E/u/depth_20_0122.png
#   inflating: dataset5/E/u/depth_20_0123.png
#   inflating: dataset5/E/u/depth_20_0124.png
#   inflating: dataset5/E/u/depth_20_0125.png
#   inflating: dataset5/E/u/depth_20_0126.png
#   inflating: dataset5/E/u/depth_20_0127.png
#   inflating: dataset5/E/u/depth_20_0128.png
#   inflating: dataset5/E/u/depth_20_0129.png
#   inflating: dataset5/E/u/depth_20_0130.png
#   inflating: dataset5/E/u/depth_20_0131.png
#   inflating: dataset5/E/u/depth_20_0132.png
#   inflating: dataset5/E/u/depth_20_0133.png
#   inflating: dataset5/E/u/depth_20_0134.png
#   inflating: dataset5/E/u/depth_20_0135.png
#   inflating: dataset5/E/u/depth_20_0136.png
#   inflating: dataset5/E/u/depth_20_0137.png
#   inflating: dataset5/E/u/depth_20_0138.png
#   inflating: dataset5/E/u/depth_20_0139.png
#   inflating: dataset5/E/u/depth_20_0140.png
#   inflating: dataset5/E/u/depth_20_0141.png
#   inflating: dataset5/E/u/depth_20_0142.png
#   inflating: dataset5/E/u/depth_20_0143.png
#   inflating: dataset5/E/u/depth_20_0144.png
#   inflating: dataset5/E/u/depth_20_0145.png
#   inflating: dataset5/E/u/depth_20_0146.png
#   inflating: dataset5/E/u/depth_20_0147.png
#   inflating: dataset5/E/u/depth_20_0148.png
#   inflating: dataset5/E/u/depth_20_0149.png
#   inflating: dataset5/E/u/depth_20_0150.png
#   inflating: dataset5/E/u/depth_20_0151.png
#   inflating: dataset5/E/u/depth_20_0152.png
#   inflating: dataset5/E/u/depth_20_0153.png
#   inflating: dataset5/E/u/depth_20_0154.png
#   inflating: dataset5/E/u/depth_20_0155.png
#   inflating: dataset5/E/u/depth_20_0156.png
#   inflating: dataset5/E/u/depth_20_0157.png
#   inflating: dataset5/E/u/depth_20_0158.png
#   inflating: dataset5/E/u/depth_20_0159.png
#   inflating: dataset5/E/u/depth_20_0160.png
#   inflating: dataset5/E/u/depth_20_0161.png
#   inflating: dataset5/E/u/depth_20_0162.png
#   inflating: dataset5/E/u/depth_20_0163.png
#   inflating: dataset5/E/u/depth_20_0164.png
#   inflating: dataset5/E/u/depth_20_0165.png
#   inflating: dataset5/E/u/depth_20_0166.png
#   inflating: dataset5/E/u/depth_20_0167.png
#   inflating: dataset5/E/u/depth_20_0168.png
#   inflating: dataset5/E/u/depth_20_0169.png
#   inflating: dataset5/E/u/depth_20_0170.png
#   inflating: dataset5/E/u/depth_20_0171.png
#   inflating: dataset5/E/u/depth_20_0172.png
#   inflating: dataset5/E/u/depth_20_0173.png
#   inflating: dataset5/E/u/depth_20_0174.png
#   inflating: dataset5/E/u/depth_20_0175.png
#   inflating: dataset5/E/u/depth_20_0176.png
#   inflating: dataset5/E/u/depth_20_0177.png
#   inflating: dataset5/E/u/depth_20_0178.png
#   inflating: dataset5/E/u/depth_20_0179.png
#   inflating: dataset5/E/u/depth_20_0180.png
#   inflating: dataset5/E/u/depth_20_0181.png
#   inflating: dataset5/E/u/depth_20_0182.png
#   inflating: dataset5/E/u/depth_20_0183.png
#   inflating: dataset5/E/u/depth_20_0184.png
#   inflating: dataset5/E/u/depth_20_0185.png
#   inflating: dataset5/E/u/depth_20_0186.png
#   inflating: dataset5/E/u/depth_20_0187.png
#   inflating: dataset5/E/u/depth_20_0188.png
#   inflating: dataset5/E/u/depth_20_0189.png
#   inflating: dataset5/E/u/depth_20_0190.png
#   inflating: dataset5/E/u/depth_20_0191.png
#   inflating: dataset5/E/u/depth_20_0192.png
#   inflating: dataset5/E/u/depth_20_0193.png
#   inflating: dataset5/E/u/depth_20_0194.png
#   inflating: dataset5/E/u/depth_20_0195.png
#   inflating: dataset5/E/u/depth_20_0196.png
#   inflating: dataset5/E/u/depth_20_0197.png
#   inflating: dataset5/E/u/depth_20_0198.png
#   inflating: dataset5/E/u/depth_20_0199.png
#   inflating: dataset5/E/u/depth_20_0200.png
#   inflating: dataset5/E/u/depth_20_0201.png
#   inflating: dataset5/E/u/depth_20_0202.png
#   inflating: dataset5/E/u/depth_20_0203.png
#   inflating: dataset5/E/u/depth_20_0204.png
#   inflating: dataset5/E/u/depth_20_0205.png
#   inflating: dataset5/E/u/depth_20_0206.png
#   inflating: dataset5/E/u/depth_20_0207.png
#   inflating: dataset5/E/u/depth_20_0208.png
#   inflating: dataset5/E/u/depth_20_0209.png
#   inflating: dataset5/E/u/depth_20_0210.png
#   inflating: dataset5/E/u/depth_20_0211.png
#   inflating: dataset5/E/u/depth_20_0212.png
#   inflating: dataset5/E/u/depth_20_0213.png
#   inflating: dataset5/E/u/depth_20_0214.png
#   inflating: dataset5/E/u/depth_20_0215.png
#   inflating: dataset5/E/u/depth_20_0216.png
#   inflating: dataset5/E/u/depth_20_0217.png
#   inflating: dataset5/E/u/depth_20_0218.png
#   inflating: dataset5/E/u/depth_20_0219.png
#   inflating: dataset5/E/u/depth_20_0220.png
#   inflating: dataset5/E/u/depth_20_0221.png
#   inflating: dataset5/E/u/depth_20_0222.png
#   inflating: dataset5/E/u/depth_20_0223.png
#   inflating: dataset5/E/u/depth_20_0224.png
#   inflating: dataset5/E/u/depth_20_0225.png
#   inflating: dataset5/E/u/depth_20_0226.png
#   inflating: dataset5/E/u/depth_20_0227.png
#   inflating: dataset5/E/u/depth_20_0228.png
#   inflating: dataset5/E/u/depth_20_0229.png
#   inflating: dataset5/E/u/depth_20_0230.png
#   inflating: dataset5/E/u/depth_20_0231.png
#   inflating: dataset5/E/u/depth_20_0232.png
#   inflating: dataset5/E/u/depth_20_0233.png
#   inflating: dataset5/E/u/depth_20_0234.png
#   inflating: dataset5/E/u/depth_20_0235.png
#   inflating: dataset5/E/u/depth_20_0236.png
#   inflating: dataset5/E/u/depth_20_0237.png
#   inflating: dataset5/E/u/depth_20_0238.png
#   inflating: dataset5/E/u/depth_20_0239.png
#   inflating: dataset5/E/u/depth_20_0240.png
#   inflating: dataset5/E/u/depth_20_0241.png
#   inflating: dataset5/E/u/depth_20_0242.png
#   inflating: dataset5/E/u/depth_20_0243.png
#   inflating: dataset5/E/u/depth_20_0244.png
#   inflating: dataset5/E/u/depth_20_0245.png
#   inflating: dataset5/E/u/depth_20_0246.png
#   inflating: dataset5/E/u/depth_20_0247.png
#   inflating: dataset5/E/u/depth_20_0248.png
#   inflating: dataset5/E/u/depth_20_0249.png
#   inflating: dataset5/E/u/depth_20_0250.png
#   inflating: dataset5/E/u/depth_20_0251.png
#   inflating: dataset5/E/u/depth_20_0252.png
#   inflating: dataset5/E/u/depth_20_0253.png
#   inflating: dataset5/E/u/depth_20_0254.png
#   inflating: dataset5/E/u/depth_20_0255.png
#   inflating: dataset5/E/u/depth_20_0256.png
#   inflating: dataset5/E/u/depth_20_0257.png
#   inflating: dataset5/E/u/depth_20_0258.png
#   inflating: dataset5/E/u/depth_20_0259.png
#   inflating: dataset5/E/u/depth_20_0260.png
#   inflating: dataset5/E/u/depth_20_0261.png
#   inflating: dataset5/E/u/depth_20_0262.png
#   inflating: dataset5/E/u/depth_20_0263.png
#   inflating: dataset5/E/u/depth_20_0264.png
#   inflating: dataset5/E/u/depth_20_0265.png
#   inflating: dataset5/E/u/depth_20_0266.png
#   inflating: dataset5/E/u/depth_20_0267.png
#   inflating: dataset5/E/u/depth_20_0268.png
#   inflating: dataset5/E/u/depth_20_0269.png
#   inflating: dataset5/E/u/depth_20_0270.png
#   inflating: dataset5/E/u/depth_20_0271.png
#   inflating: dataset5/E/u/depth_20_0272.png
#   inflating: dataset5/E/u/depth_20_0273.png
#   inflating: dataset5/E/u/depth_20_0274.png
#   inflating: dataset5/E/u/depth_20_0275.png
#   inflating: dataset5/E/u/depth_20_0276.png
#   inflating: dataset5/E/u/depth_20_0277.png
#   inflating: dataset5/E/u/depth_20_0278.png
#   inflating: dataset5/E/u/depth_20_0279.png
#   inflating: dataset5/E/u/depth_20_0280.png
#   inflating: dataset5/E/u/depth_20_0281.png
#   inflating: dataset5/E/u/depth_20_0282.png
#   inflating: dataset5/E/u/depth_20_0283.png
#   inflating: dataset5/E/u/depth_20_0284.png
#   inflating: dataset5/E/u/depth_20_0285.png
#   inflating: dataset5/E/u/depth_20_0286.png
#   inflating: dataset5/E/u/depth_20_0287.png
#   inflating: dataset5/E/u/depth_20_0288.png
#   inflating: dataset5/E/u/depth_20_0289.png
#   inflating: dataset5/E/u/depth_20_0290.png
#   inflating: dataset5/E/u/depth_20_0291.png
#   inflating: dataset5/E/u/depth_20_0292.png
#   inflating: dataset5/E/u/depth_20_0293.png
#   inflating: dataset5/E/u/depth_20_0294.png
#   inflating: dataset5/E/u/depth_20_0295.png
#   inflating: dataset5/E/u/depth_20_0296.png
#   inflating: dataset5/E/u/depth_20_0297.png
#   inflating: dataset5/E/u/depth_20_0298.png
#   inflating: dataset5/E/u/depth_20_0299.png
#   inflating: dataset5/E/u/depth_20_0300.png
#   inflating: dataset5/E/u/depth_20_0301.png
#   inflating: dataset5/E/u/depth_20_0302.png
#   inflating: dataset5/E/u/depth_20_0303.png
#   inflating: dataset5/E/u/depth_20_0304.png
#   inflating: dataset5/E/u/depth_20_0305.png
#   inflating: dataset5/E/u/depth_20_0306.png
#   inflating: dataset5/E/u/depth_20_0307.png
#   inflating: dataset5/E/u/depth_20_0308.png
#   inflating: dataset5/E/u/depth_20_0309.png
#   inflating: dataset5/E/u/depth_20_0310.png
#   inflating: dataset5/E/u/depth_20_0311.png
#   inflating: dataset5/E/u/depth_20_0312.png
#   inflating: dataset5/E/u/depth_20_0313.png
#   inflating: dataset5/E/u/depth_20_0314.png
#   inflating: dataset5/E/u/depth_20_0315.png
#   inflating: dataset5/E/u/depth_20_0316.png
#   inflating: dataset5/E/u/depth_20_0317.png
#   inflating: dataset5/E/u/depth_20_0318.png
#   inflating: dataset5/E/u/depth_20_0319.png
#   inflating: dataset5/E/u/depth_20_0320.png
#   inflating: dataset5/E/u/depth_20_0321.png
#   inflating: dataset5/E/u/depth_20_0322.png
#   inflating: dataset5/E/u/depth_20_0323.png
#   inflating: dataset5/E/u/depth_20_0324.png
#   inflating: dataset5/E/u/depth_20_0325.png
#   inflating: dataset5/E/u/depth_20_0326.png
#   inflating: dataset5/E/u/depth_20_0327.png
#   inflating: dataset5/E/u/depth_20_0328.png
#   inflating: dataset5/E/u/depth_20_0329.png
#   inflating: dataset5/E/u/depth_20_0330.png
#   inflating: dataset5/E/u/depth_20_0331.png
#   inflating: dataset5/E/u/depth_20_0332.png
#   inflating: dataset5/E/u/depth_20_0333.png
#   inflating: dataset5/E/u/depth_20_0334.png
#   inflating: dataset5/E/u/depth_20_0335.png
#   inflating: dataset5/E/u/depth_20_0336.png
#   inflating: dataset5/E/u/depth_20_0337.png
#   inflating: dataset5/E/u/depth_20_0338.png
#   inflating: dataset5/E/u/depth_20_0339.png
#   inflating: dataset5/E/u/depth_20_0340.png
#   inflating: dataset5/E/u/depth_20_0341.png
#   inflating: dataset5/E/u/depth_20_0342.png
#   inflating: dataset5/E/u/depth_20_0343.png
#   inflating: dataset5/E/u/depth_20_0344.png
#   inflating: dataset5/E/u/depth_20_0345.png
#   inflating: dataset5/E/u/depth_20_0346.png
#   inflating: dataset5/E/u/depth_20_0347.png
#   inflating: dataset5/E/u/depth_20_0348.png
#   inflating: dataset5/E/u/depth_20_0349.png
#   inflating: dataset5/E/u/depth_20_0350.png
#   inflating: dataset5/E/u/depth_20_0351.png
#   inflating: dataset5/E/u/depth_20_0352.png
#   inflating: dataset5/E/u/depth_20_0353.png
#   inflating: dataset5/E/u/depth_20_0354.png
#   inflating: dataset5/E/u/depth_20_0355.png
#   inflating: dataset5/E/u/depth_20_0356.png
#   inflating: dataset5/E/u/depth_20_0357.png
#   inflating: dataset5/E/u/depth_20_0358.png
#   inflating: dataset5/E/u/depth_20_0359.png
#   inflating: dataset5/E/u/depth_20_0360.png
#   inflating: dataset5/E/u/depth_20_0361.png
#   inflating: dataset5/E/u/depth_20_0362.png
#   inflating: dataset5/E/u/depth_20_0363.png
#   inflating: dataset5/E/u/depth_20_0364.png
#   inflating: dataset5/E/u/depth_20_0365.png
#   inflating: dataset5/E/u/depth_20_0366.png
#   inflating: dataset5/E/u/depth_20_0367.png
#   inflating: dataset5/E/u/depth_20_0368.png
#   inflating: dataset5/E/u/depth_20_0369.png
#   inflating: dataset5/E/u/depth_20_0370.png
#   inflating: dataset5/E/u/depth_20_0371.png
#   inflating: dataset5/E/u/depth_20_0372.png
#   inflating: dataset5/E/u/depth_20_0373.png
#   inflating: dataset5/E/u/depth_20_0374.png
#   inflating: dataset5/E/u/depth_20_0375.png
#   inflating: dataset5/E/u/depth_20_0376.png
#   inflating: dataset5/E/u/depth_20_0377.png
#   inflating: dataset5/E/u/depth_20_0378.png
#   inflating: dataset5/E/u/depth_20_0379.png
#   inflating: dataset5/E/u/depth_20_0380.png
#   inflating: dataset5/E/u/depth_20_0381.png
#   inflating: dataset5/E/u/depth_20_0382.png
#   inflating: dataset5/E/u/depth_20_0383.png
#   inflating: dataset5/E/u/depth_20_0384.png
#   inflating: dataset5/E/u/depth_20_0385.png
#   inflating: dataset5/E/u/depth_20_0386.png
#   inflating: dataset5/E/u/depth_20_0387.png
#   inflating: dataset5/E/u/depth_20_0388.png
#   inflating: dataset5/E/u/depth_20_0389.png
#   inflating: dataset5/E/u/depth_20_0390.png
#   inflating: dataset5/E/u/depth_20_0391.png
#   inflating: dataset5/E/u/depth_20_0392.png
#   inflating: dataset5/E/u/depth_20_0393.png
#   inflating: dataset5/E/u/depth_20_0394.png
#   inflating: dataset5/E/u/depth_20_0395.png
#   inflating: dataset5/E/u/depth_20_0396.png
#   inflating: dataset5/E/u/depth_20_0397.png
#   inflating: dataset5/E/u/depth_20_0398.png
#   inflating: dataset5/E/u/depth_20_0399.png
#   inflating: dataset5/E/u/depth_20_0400.png
#   inflating: dataset5/E/u/depth_20_0401.png
#   inflating: dataset5/E/u/depth_20_0402.png
#   inflating: dataset5/E/u/depth_20_0403.png
#   inflating: dataset5/E/u/depth_20_0404.png
#   inflating: dataset5/E/u/depth_20_0405.png
#   inflating: dataset5/E/u/depth_20_0406.png
#   inflating: dataset5/E/u/depth_20_0407.png
#   inflating: dataset5/E/u/depth_20_0408.png
#   inflating: dataset5/E/u/depth_20_0409.png
#   inflating: dataset5/E/u/depth_20_0410.png
#   inflating: dataset5/E/u/depth_20_0411.png
#   inflating: dataset5/E/u/depth_20_0412.png
#   inflating: dataset5/E/u/depth_20_0413.png
#   inflating: dataset5/E/u/depth_20_0414.png
#   inflating: dataset5/E/u/depth_20_0415.png
#   inflating: dataset5/E/u/depth_20_0416.png
#   inflating: dataset5/E/u/depth_20_0417.png
#   inflating: dataset5/E/u/depth_20_0418.png
#   inflating: dataset5/E/u/depth_20_0419.png
#   inflating: dataset5/E/u/depth_20_0420.png
#   inflating: dataset5/E/u/depth_20_0421.png
#   inflating: dataset5/E/u/depth_20_0422.png
#   inflating: dataset5/E/u/depth_20_0423.png
#   inflating: dataset5/E/u/depth_20_0424.png
#   inflating: dataset5/E/u/depth_20_0425.png
#   inflating: dataset5/E/u/depth_20_0426.png
#   inflating: dataset5/E/u/depth_20_0427.png
#   inflating: dataset5/E/u/depth_20_0428.png
#   inflating: dataset5/E/u/depth_20_0429.png
#   inflating: dataset5/E/u/depth_20_0430.png
#   inflating: dataset5/E/u/depth_20_0431.png
#   inflating: dataset5/E/u/depth_20_0432.png
#   inflating: dataset5/E/u/depth_20_0433.png
#   inflating: dataset5/E/u/depth_20_0434.png
#   inflating: dataset5/E/u/depth_20_0435.png
#   inflating: dataset5/E/u/depth_20_0436.png
#   inflating: dataset5/E/u/depth_20_0437.png
#   inflating: dataset5/E/u/depth_20_0438.png
#   inflating: dataset5/E/u/depth_20_0439.png
#   inflating: dataset5/E/u/depth_20_0440.png
#   inflating: dataset5/E/u/depth_20_0441.png
#   inflating: dataset5/E/u/depth_20_0442.png
#   inflating: dataset5/E/u/depth_20_0443.png
#   inflating: dataset5/E/u/depth_20_0444.png
#   inflating: dataset5/E/u/depth_20_0445.png
#   inflating: dataset5/E/u/depth_20_0446.png
#   inflating: dataset5/E/u/depth_20_0447.png
#   inflating: dataset5/E/u/depth_20_0448.png
#   inflating: dataset5/E/u/depth_20_0449.png
#   inflating: dataset5/E/u/depth_20_0450.png
#   inflating: dataset5/E/u/depth_20_0451.png
#   inflating: dataset5/E/u/depth_20_0452.png
#   inflating: dataset5/E/u/depth_20_0453.png
#   inflating: dataset5/E/u/depth_20_0454.png
#   inflating: dataset5/E/u/depth_20_0455.png
#   inflating: dataset5/E/u/depth_20_0456.png
#   inflating: dataset5/E/u/depth_20_0457.png
#   inflating: dataset5/E/u/depth_20_0458.png
#   inflating: dataset5/E/u/depth_20_0459.png
#   inflating: dataset5/E/u/depth_20_0460.png
#   inflating: dataset5/E/u/depth_20_0461.png
#   inflating: dataset5/E/u/depth_20_0462.png
#   inflating: dataset5/E/u/depth_20_0463.png
#   inflating: dataset5/E/u/depth_20_0464.png
#   inflating: dataset5/E/u/depth_20_0465.png
#   inflating: dataset5/E/u/depth_20_0466.png
#   inflating: dataset5/E/u/depth_20_0467.png
#   inflating: dataset5/E/u/depth_20_0468.png
#   inflating: dataset5/E/u/depth_20_0469.png
#   inflating: dataset5/E/u/depth_20_0470.png
#   inflating: dataset5/E/u/depth_20_0471.png
#   inflating: dataset5/E/u/depth_20_0472.png
#   inflating: dataset5/E/u/depth_20_0473.png
#   inflating: dataset5/E/u/depth_20_0474.png
#   inflating: dataset5/E/u/depth_20_0475.png
#   inflating: dataset5/E/u/depth_20_0476.png
#   inflating: dataset5/E/u/depth_20_0477.png
#   inflating: dataset5/E/u/depth_20_0478.png
#   inflating: dataset5/E/u/depth_20_0479.png
#   inflating: dataset5/E/u/depth_20_0480.png
#   inflating: dataset5/E/u/depth_20_0481.png
#   inflating: dataset5/E/u/depth_20_0482.png
#   inflating: dataset5/E/u/depth_20_0483.png
#   inflating: dataset5/E/u/depth_20_0484.png
#   inflating: dataset5/E/u/depth_20_0485.png
#   inflating: dataset5/E/u/depth_20_0486.png
#   inflating: dataset5/E/u/depth_20_0487.png
#   inflating: dataset5/E/u/depth_20_0488.png
#   inflating: dataset5/E/u/depth_20_0489.png
#   inflating: dataset5/E/u/depth_20_0490.png
#   inflating: dataset5/E/u/depth_20_0491.png
#   inflating: dataset5/E/u/depth_20_0492.png
#   inflating: dataset5/E/u/depth_20_0493.png
#   inflating: dataset5/E/u/depth_20_0494.png
#   inflating: dataset5/E/u/depth_20_0495.png
#   inflating: dataset5/E/u/depth_20_0496.png
#   inflating: dataset5/E/u/depth_20_0497.png
#   inflating: dataset5/E/u/depth_20_0498.png
#   inflating: dataset5/E/u/depth_20_0499.png
#   inflating: dataset5/E/u/depth_20_0500.png
#   inflating: dataset5/E/u/depth_20_0501.png
#   inflating: dataset5/E/u/depth_20_0502.png
#   inflating: dataset5/E/u/depth_20_0503.png
#   inflating: dataset5/E/u/depth_20_0504.png
#   inflating: dataset5/E/u/depth_20_0505.png
#   inflating: dataset5/E/u/depth_20_0506.png
#   inflating: dataset5/E/u/depth_20_0507.png
#   inflating: dataset5/E/u/depth_20_0508.png
#   inflating: dataset5/E/u/depth_20_0509.png
#   inflating: dataset5/E/u/depth_20_0510.png
#   inflating: dataset5/E/u/depth_20_0511.png
#   inflating: dataset5/E/u/depth_20_0512.png
#   inflating: dataset5/E/u/depth_20_0513.png
#   inflating: dataset5/E/u/depth_20_0514.png
#   inflating: dataset5/E/u/depth_20_0515.png
#   inflating: dataset5/E/u/depth_20_0516.png
#   inflating: dataset5/E/u/depth_20_0517.png
#   inflating: dataset5/E/u/depth_20_0518.png
#   inflating: dataset5/E/u/depth_20_0519.png
#   inflating: dataset5/E/u/depth_20_0520.png
#   inflating: dataset5/E/u/depth_20_0521.png
#   inflating: dataset5/E/u/depth_20_0522.png
#   inflating: dataset5/E/u/depth_20_0523.png
#   inflating: dataset5/E/u/depth_20_0524.png
#   inflating: dataset5/E/u/depth_20_0525.png
#   inflating: dataset5/E/u/depth_20_0526.png
#   inflating: dataset5/E/u/depth_20_0527.png
#   inflating: dataset5/E/u/depth_20_0528.png
#   inflating: dataset5/E/u/depth_20_0529.png
#   inflating: dataset5/E/u/depth_20_0530.png
#   inflating: dataset5/E/v/color_21_0002.png
#   inflating: dataset5/E/v/color_21_0003.png
#   inflating: dataset5/E/v/color_21_0004.png
#   inflating: dataset5/E/v/color_21_0005.png
#   inflating: dataset5/E/v/color_21_0006.png
#   inflating: dataset5/E/v/color_21_0007.png
#   inflating: dataset5/E/v/color_21_0008.png
#   inflating: dataset5/E/v/color_21_0009.png
#   inflating: dataset5/E/v/color_21_0010.png
#   inflating: dataset5/E/v/color_21_0011.png
#   inflating: dataset5/E/v/color_21_0012.png
#   inflating: dataset5/E/v/color_21_0013.png
#   inflating: dataset5/E/v/color_21_0014.png
#   inflating: dataset5/E/v/color_21_0015.png
#   inflating: dataset5/E/v/color_21_0016.png
#   inflating: dataset5/E/v/color_21_0017.png
#   inflating: dataset5/E/v/color_21_0018.png
#   inflating: dataset5/E/v/color_21_0019.png
#   inflating: dataset5/E/v/color_21_0020.png
#   inflating: dataset5/E/v/color_21_0021.png
#   inflating: dataset5/E/v/color_21_0022.png
#   inflating: dataset5/E/v/color_21_0023.png
#   inflating: dataset5/E/v/color_21_0024.png
#   inflating: dataset5/E/v/color_21_0025.png
#   inflating: dataset5/E/v/color_21_0026.png
#   inflating: dataset5/E/v/color_21_0027.png
#   inflating: dataset5/E/v/color_21_0028.png
#   inflating: dataset5/E/v/color_21_0029.png
#   inflating: dataset5/E/v/color_21_0030.png
#   inflating: dataset5/E/v/color_21_0031.png
#   inflating: dataset5/E/v/color_21_0032.png
#   inflating: dataset5/E/v/color_21_0033.png
#   inflating: dataset5/E/v/color_21_0034.png
#   inflating: dataset5/E/v/color_21_0035.png
#   inflating: dataset5/E/v/color_21_0036.png
#   inflating: dataset5/E/v/color_21_0037.png
#   inflating: dataset5/E/v/color_21_0038.png
#   inflating: dataset5/E/v/color_21_0039.png
#   inflating: dataset5/E/v/color_21_0040.png
#   inflating: dataset5/E/v/color_21_0041.png
#   inflating: dataset5/E/v/color_21_0042.png
#   inflating: dataset5/E/v/color_21_0043.png
#   inflating: dataset5/E/v/color_21_0044.png
#   inflating: dataset5/E/v/color_21_0045.png
#   inflating: dataset5/E/v/color_21_0046.png
#   inflating: dataset5/E/v/color_21_0047.png
#   inflating: dataset5/E/v/color_21_0048.png
#   inflating: dataset5/E/v/color_21_0049.png
#   inflating: dataset5/E/v/color_21_0050.png
#   inflating: dataset5/E/v/color_21_0051.png
#   inflating: dataset5/E/v/color_21_0052.png
#   inflating: dataset5/E/v/color_21_0053.png
#   inflating: dataset5/E/v/color_21_0054.png
#   inflating: dataset5/E/v/color_21_0055.png
#   inflating: dataset5/E/v/color_21_0056.png
#   inflating: dataset5/E/v/color_21_0057.png
#   inflating: dataset5/E/v/color_21_0058.png
#   inflating: dataset5/E/v/color_21_0059.png
#   inflating: dataset5/E/v/color_21_0060.png
#   inflating: dataset5/E/v/color_21_0061.png
#   inflating: dataset5/E/v/color_21_0062.png
#   inflating: dataset5/E/v/color_21_0063.png
#   inflating: dataset5/E/v/color_21_0064.png
#   inflating: dataset5/E/v/color_21_0065.png
#   inflating: dataset5/E/v/color_21_0066.png
#   inflating: dataset5/E/v/color_21_0067.png
#   inflating: dataset5/E/v/color_21_0068.png
#   inflating: dataset5/E/v/color_21_0069.png
#   inflating: dataset5/E/v/color_21_0070.png
#   inflating: dataset5/E/v/color_21_0071.png
#   inflating: dataset5/E/v/color_21_0072.png
#   inflating: dataset5/E/v/color_21_0073.png
#   inflating: dataset5/E/v/color_21_0074.png
#   inflating: dataset5/E/v/color_21_0075.png
#   inflating: dataset5/E/v/color_21_0076.png
#   inflating: dataset5/E/v/color_21_0077.png
#   inflating: dataset5/E/v/color_21_0078.png
#   inflating: dataset5/E/v/color_21_0079.png
#   inflating: dataset5/E/v/color_21_0080.png
#   inflating: dataset5/E/v/color_21_0081.png
#   inflating: dataset5/E/v/color_21_0082.png
#   inflating: dataset5/E/v/color_21_0083.png
#   inflating: dataset5/E/v/color_21_0084.png
#   inflating: dataset5/E/v/color_21_0085.png
#   inflating: dataset5/E/v/color_21_0086.png
#   inflating: dataset5/E/v/color_21_0087.png
#   inflating: dataset5/E/v/color_21_0088.png
#   inflating: dataset5/E/v/color_21_0089.png
#   inflating: dataset5/E/v/color_21_0090.png
#   inflating: dataset5/E/v/color_21_0091.png
#   inflating: dataset5/E/v/color_21_0092.png
#   inflating: dataset5/E/v/color_21_0093.png
#   inflating: dataset5/E/v/color_21_0094.png
#   inflating: dataset5/E/v/color_21_0095.png
#   inflating: dataset5/E/v/color_21_0096.png
#   inflating: dataset5/E/v/color_21_0097.png
#   inflating: dataset5/E/v/color_21_0098.png
#   inflating: dataset5/E/v/color_21_0099.png
#   inflating: dataset5/E/v/color_21_0100.png
#   inflating: dataset5/E/v/color_21_0101.png
#   inflating: dataset5/E/v/color_21_0102.png
#   inflating: dataset5/E/v/color_21_0103.png
#   inflating: dataset5/E/v/color_21_0104.png
#   inflating: dataset5/E/v/color_21_0105.png
#   inflating: dataset5/E/v/color_21_0106.png
#   inflating: dataset5/E/v/color_21_0107.png
#   inflating: dataset5/E/v/color_21_0108.png
#   inflating: dataset5/E/v/color_21_0109.png
#   inflating: dataset5/E/v/color_21_0110.png
#   inflating: dataset5/E/v/color_21_0111.png
#   inflating: dataset5/E/v/color_21_0112.png
#   inflating: dataset5/E/v/color_21_0113.png
#   inflating: dataset5/E/v/color_21_0114.png
#   inflating: dataset5/E/v/color_21_0115.png
#   inflating: dataset5/E/v/color_21_0116.png
#   inflating: dataset5/E/v/color_21_0117.png
#   inflating: dataset5/E/v/color_21_0118.png
#   inflating: dataset5/E/v/color_21_0119.png
#   inflating: dataset5/E/v/color_21_0120.png
#   inflating: dataset5/E/v/color_21_0121.png
#   inflating: dataset5/E/v/color_21_0122.png
#   inflating: dataset5/E/v/color_21_0123.png
#   inflating: dataset5/E/v/color_21_0124.png
#   inflating: dataset5/E/v/color_21_0125.png
#   inflating: dataset5/E/v/color_21_0126.png
#   inflating: dataset5/E/v/color_21_0127.png
#   inflating: dataset5/E/v/color_21_0128.png
#   inflating: dataset5/E/v/color_21_0129.png
#   inflating: dataset5/E/v/color_21_0130.png
#   inflating: dataset5/E/v/color_21_0131.png
#   inflating: dataset5/E/v/color_21_0132.png
#   inflating: dataset5/E/v/color_21_0133.png
#   inflating: dataset5/E/v/color_21_0134.png
#   inflating: dataset5/E/v/color_21_0135.png
#   inflating: dataset5/E/v/color_21_0136.png
#   inflating: dataset5/E/v/color_21_0137.png
#   inflating: dataset5/E/v/color_21_0138.png
#   inflating: dataset5/E/v/color_21_0139.png
#   inflating: dataset5/E/v/color_21_0140.png
#   inflating: dataset5/E/v/color_21_0141.png
#   inflating: dataset5/E/v/color_21_0142.png
#   inflating: dataset5/E/v/color_21_0143.png
#   inflating: dataset5/E/v/color_21_0144.png
#   inflating: dataset5/E/v/color_21_0145.png
#   inflating: dataset5/E/v/color_21_0146.png
#   inflating: dataset5/E/v/color_21_0147.png
#   inflating: dataset5/E/v/color_21_0148.png
#   inflating: dataset5/E/v/color_21_0149.png
#   inflating: dataset5/E/v/color_21_0150.png
#   inflating: dataset5/E/v/color_21_0151.png
#   inflating: dataset5/E/v/color_21_0152.png
#   inflating: dataset5/E/v/color_21_0153.png
#   inflating: dataset5/E/v/color_21_0154.png
#   inflating: dataset5/E/v/color_21_0155.png
#   inflating: dataset5/E/v/color_21_0156.png
#   inflating: dataset5/E/v/color_21_0157.png
#   inflating: dataset5/E/v/color_21_0158.png
#   inflating: dataset5/E/v/color_21_0159.png
#   inflating: dataset5/E/v/color_21_0160.png
#   inflating: dataset5/E/v/color_21_0161.png
#   inflating: dataset5/E/v/color_21_0162.png
#   inflating: dataset5/E/v/color_21_0163.png
#   inflating: dataset5/E/v/color_21_0164.png
#   inflating: dataset5/E/v/color_21_0165.png
#   inflating: dataset5/E/v/color_21_0166.png
#   inflating: dataset5/E/v/color_21_0167.png
#   inflating: dataset5/E/v/color_21_0168.png
#   inflating: dataset5/E/v/color_21_0169.png
#   inflating: dataset5/E/v/color_21_0170.png
#   inflating: dataset5/E/v/color_21_0171.png
#   inflating: dataset5/E/v/color_21_0172.png
#   inflating: dataset5/E/v/color_21_0173.png
#   inflating: dataset5/E/v/color_21_0174.png
#   inflating: dataset5/E/v/color_21_0175.png
#   inflating: dataset5/E/v/color_21_0176.png
#   inflating: dataset5/E/v/color_21_0177.png
#   inflating: dataset5/E/v/color_21_0178.png
#   inflating: dataset5/E/v/color_21_0179.png
#   inflating: dataset5/E/v/color_21_0180.png
#   inflating: dataset5/E/v/color_21_0181.png
#   inflating: dataset5/E/v/color_21_0182.png
#   inflating: dataset5/E/v/color_21_0183.png
#   inflating: dataset5/E/v/color_21_0184.png
#   inflating: dataset5/E/v/color_21_0185.png
#   inflating: dataset5/E/v/color_21_0186.png
#   inflating: dataset5/E/v/color_21_0187.png
#   inflating: dataset5/E/v/color_21_0188.png
#   inflating: dataset5/E/v/color_21_0189.png
#   inflating: dataset5/E/v/color_21_0190.png
#   inflating: dataset5/E/v/color_21_0191.png
#   inflating: dataset5/E/v/color_21_0192.png
#   inflating: dataset5/E/v/color_21_0193.png
#   inflating: dataset5/E/v/color_21_0194.png
#   inflating: dataset5/E/v/color_21_0195.png
#   inflating: dataset5/E/v/color_21_0196.png
#   inflating: dataset5/E/v/color_21_0197.png
#   inflating: dataset5/E/v/color_21_0198.png
#   inflating: dataset5/E/v/color_21_0199.png
#   inflating: dataset5/E/v/color_21_0200.png
#   inflating: dataset5/E/v/color_21_0201.png
#   inflating: dataset5/E/v/color_21_0202.png
#   inflating: dataset5/E/v/color_21_0203.png
#   inflating: dataset5/E/v/color_21_0204.png
#   inflating: dataset5/E/v/color_21_0205.png
#   inflating: dataset5/E/v/color_21_0206.png
#   inflating: dataset5/E/v/color_21_0207.png
#   inflating: dataset5/E/v/color_21_0208.png
#   inflating: dataset5/E/v/color_21_0209.png
#   inflating: dataset5/E/v/color_21_0210.png
#   inflating: dataset5/E/v/color_21_0211.png
#   inflating: dataset5/E/v/color_21_0212.png
#   inflating: dataset5/E/v/color_21_0213.png
# ...
#   inflating: dataset5/E/y/depth_24_0176.png
#   inflating: dataset5/E/y/depth_24_0177.png
#   inflating: dataset5/E/y/depth_24_0178.png
#   inflating: dataset5/E/y/depth_24_0179.png
#   inflating: dataset5/E/y/depth_24_0180.png
#   inflating: dataset5/E/y/depth_24_0181.png
#   inflating: dataset5/E/y/depth_24_0182.png
#   inflating: dataset5/E/y/depth_24_0183.png
#   inflating: dataset5/E/y/depth_24_0184.png
#   inflating: dataset5/E/y/depth_24_0185.png
#   inflating: dataset5/E/y/depth_24_0186.png
#   inflating: dataset5/E/y/depth_24_0187.png
#   inflating: dataset5/E/y/depth_24_0188.png
#   inflating: dataset5/E/y/depth_24_0189.png
#   inflating: dataset5/E/y/depth_24_0190.png
#   inflating: dataset5/E/y/depth_24_0191.png
#   inflating: dataset5/E/y/depth_24_0192.png
#   inflating: dataset5/E/y/depth_24_0193.png
#   inflating: dataset5/E/y/depth_24_0194.png
#   inflating: dataset5/E/y/depth_24_0195.png
#   inflating: dataset5/E/y/depth_24_0196.png
#   inflating: dataset5/E/y/depth_24_0197.png
#   inflating: dataset5/E/y/depth_24_0198.png
#   inflating: dataset5/E/y/depth_24_0199.png
#   inflating: dataset5/E/y/depth_24_0200.png
#   inflating: dataset5/E/y/depth_24_0201.png
#   inflating: dataset5/E/y/depth_24_0202.png
#   inflating: dataset5/E/y/depth_24_0203.png
#   inflating: dataset5/E/y/depth_24_0204.png
#   inflating: dataset5/E/y/depth_24_0205.png
#   inflating: dataset5/E/y/depth_24_0206.png
#   inflating: dataset5/E/y/depth_24_0207.png
#   inflating: dataset5/E/y/depth_24_0208.png
#   inflating: dataset5/E/y/depth_24_0209.png
#   inflating: dataset5/E/y/depth_24_0210.png
#   inflating: dataset5/E/y/depth_24_0211.png
#   inflating: dataset5/E/y/depth_24_0212.png
#   inflating: dataset5/E/y/depth_24_0213.png
#   inflating: dataset5/E/y/depth_24_0214.png
#   inflating: dataset5/E/y/depth_24_0215.png
#   inflating: dataset5/E/y/depth_24_0216.png
#   inflating: dataset5/E/y/depth_24_0217.png
#   inflating: dataset5/E/y/depth_24_0218.png
#   inflating: dataset5/E/y/depth_24_0219.png
#   inflating: dataset5/E/y/depth_24_0220.png
#   inflating: dataset5/E/y/depth_24_0221.png
#   inflating: dataset5/E/y/depth_24_0222.png
#   inflating: dataset5/E/y/depth_24_0223.png
#   inflating: dataset5/E/y/depth_24_0224.png
#   inflating: dataset5/E/y/depth_24_0225.png
#   inflating: dataset5/E/y/depth_24_0226.png
#   inflating: dataset5/E/y/depth_24_0227.png
#   inflating: dataset5/E/y/depth_24_0228.png
#   inflating: dataset5/E/y/depth_24_0229.png
#   inflating: dataset5/E/y/depth_24_0230.png
#   inflating: dataset5/E/y/depth_24_0231.png
#   inflating: dataset5/E/y/depth_24_0232.png
#   inflating: dataset5/E/y/depth_24_0233.png
#   inflating: dataset5/E/y/depth_24_0234.png
#   inflating: dataset5/E/y/depth_24_0235.png
#   inflating: dataset5/E/y/depth_24_0236.png
#   inflating: dataset5/E/y/depth_24_0237.png
#   inflating: dataset5/E/y/depth_24_0238.png
#   inflating: dataset5/E/y/depth_24_0239.png
#   inflating: dataset5/E/y/depth_24_0240.png
#   inflating: dataset5/E/y/depth_24_0241.png
#   inflating: dataset5/E/y/depth_24_0242.png
#   inflating: dataset5/E/y/depth_24_0243.png
#   inflating: dataset5/E/y/depth_24_0244.png
#   inflating: dataset5/E/y/depth_24_0245.png
#   inflating: dataset5/E/y/depth_24_0246.png
#   inflating: dataset5/E/y/depth_24_0247.png
#   inflating: dataset5/E/y/depth_24_0248.png
#   inflating: dataset5/E/y/depth_24_0249.png
#   inflating: dataset5/E/y/depth_24_0250.png
#   inflating: dataset5/E/y/depth_24_0251.png
#   inflating: dataset5/E/y/depth_24_0252.png
#   inflating: dataset5/E/y/depth_24_0253.png
#   inflating: dataset5/E/y/depth_24_0254.png
#   inflating: dataset5/E/y/depth_24_0255.png
#   inflating: dataset5/E/y/depth_24_0256.png
#   inflating: dataset5/E/y/depth_24_0257.png
#   inflating: dataset5/E/y/depth_24_0258.png
#   inflating: dataset5/E/y/depth_24_0259.png
#   inflating: dataset5/E/y/depth_24_0260.png
#   inflating: dataset5/E/y/depth_24_0261.png
#   inflating: dataset5/E/y/depth_24_0262.png
#   inflating: dataset5/E/y/depth_24_0263.png
#   inflating: dataset5/E/y/depth_24_0264.png
#   inflating: dataset5/E/y/depth_24_0265.png
#   inflating: dataset5/E/y/depth_24_0266.png
#   inflating: dataset5/E/y/depth_24_0267.png
#   inflating: dataset5/E/y/depth_24_0268.png
#   inflating: dataset5/E/y/depth_24_0269.png
#   inflating: dataset5/E/y/depth_24_0270.png
#   inflating: dataset5/E/y/depth_24_0271.png
#   inflating: dataset5/E/y/depth_24_0272.png
#   inflating: dataset5/E/y/depth_24_0273.png
#   inflating: dataset5/E/y/depth_24_0274.png
#   inflating: dataset5/E/y/depth_24_0275.png
#   inflating: dataset5/E/y/depth_24_0276.png
#   inflating: dataset5/E/y/depth_24_0277.png
#   inflating: dataset5/E/y/depth_24_0278.png
#   inflating: dataset5/E/y/depth_24_0279.png
#   inflating: dataset5/E/y/depth_24_0280.png
#   inflating: dataset5/E/y/depth_24_0281.png
#   inflating: dataset5/E/y/depth_24_0282.png
#   inflating: dataset5/E/y/depth_24_0283.png
#   inflating: dataset5/E/y/depth_24_0284.png
#   inflating: dataset5/E/y/depth_24_0285.png
#   inflating: dataset5/E/y/depth_24_0286.png
#   inflating: dataset5/E/y/depth_24_0287.png
#   inflating: dataset5/E/y/depth_24_0288.png
#   inflating: dataset5/E/y/depth_24_0289.png
#   inflating: dataset5/E/y/depth_24_0290.png
#   inflating: dataset5/E/y/depth_24_0291.png
#   inflating: dataset5/E/y/depth_24_0292.png
#   inflating: dataset5/E/y/depth_24_0293.png
#   inflating: dataset5/E/y/depth_24_0294.png
#   inflating: dataset5/E/y/depth_24_0295.png
#   inflating: dataset5/E/y/depth_24_0296.png
#   inflating: dataset5/E/y/depth_24_0297.png
#   inflating: dataset5/E/y/depth_24_0298.png
#   inflating: dataset5/E/y/depth_24_0299.png
#   inflating: dataset5/E/y/depth_24_0300.png
#   inflating: dataset5/E/y/depth_24_0301.png
#   inflating: dataset5/E/y/depth_24_0302.png
#   inflating: dataset5/E/y/depth_24_0303.png
#   inflating: dataset5/E/y/depth_24_0304.png
#   inflating: dataset5/E/y/depth_24_0305.png
#   inflating: dataset5/E/y/depth_24_0306.png
#   inflating: dataset5/E/y/depth_24_0307.png
#   inflating: dataset5/E/y/depth_24_0308.png
#   inflating: dataset5/E/y/depth_24_0309.png
#   inflating: dataset5/E/y/depth_24_0310.png
#   inflating: dataset5/E/y/depth_24_0311.png
#   inflating: dataset5/E/y/depth_24_0312.png
#   inflating: dataset5/E/y/depth_24_0313.png
#   inflating: dataset5/E/y/depth_24_0314.png
#   inflating: dataset5/E/y/depth_24_0315.png
#   inflating: dataset5/E/y/depth_24_0316.png
#   inflating: dataset5/E/y/depth_24_0317.png
#   inflating: dataset5/E/y/depth_24_0318.png
#   inflating: dataset5/E/y/depth_24_0319.png
#   inflating: dataset5/E/y/depth_24_0320.png
#   inflating: dataset5/E/y/depth_24_0321.png
#   inflating: dataset5/E/y/depth_24_0322.png
#   inflating: dataset5/E/y/depth_24_0323.png
#   inflating: dataset5/E/y/depth_24_0324.png
#   inflating: dataset5/E/y/depth_24_0325.png
#   inflating: dataset5/E/y/depth_24_0326.png
#   inflating: dataset5/E/y/depth_24_0327.png
#   inflating: dataset5/E/y/depth_24_0328.png
#   inflating: dataset5/E/y/depth_24_0329.png
#   inflating: dataset5/E/y/depth_24_0330.png
#   inflating: dataset5/E/y/depth_24_0331.png
#   inflating: dataset5/E/y/depth_24_0332.png
#   inflating: dataset5/E/y/depth_24_0333.png
#   inflating: dataset5/E/y/depth_24_0334.png
#   inflating: dataset5/E/y/depth_24_0335.png
#   inflating: dataset5/E/y/depth_24_0336.png
#   inflating: dataset5/E/y/depth_24_0337.png
#   inflating: dataset5/E/y/depth_24_0338.png
#   inflating: dataset5/E/y/depth_24_0339.png
#   inflating: dataset5/E/y/depth_24_0340.png
#   inflating: dataset5/E/y/depth_24_0341.png
#   inflating: dataset5/E/y/depth_24_0342.png
#   inflating: dataset5/E/y/depth_24_0343.png
#   inflating: dataset5/E/y/depth_24_0344.png
#   inflating: dataset5/E/y/depth_24_0345.png
#   inflating: dataset5/E/y/depth_24_0346.png
#   inflating: dataset5/E/y/depth_24_0347.png
#   inflating: dataset5/E/y/depth_24_0348.png
#   inflating: dataset5/E/y/depth_24_0349.png
#   inflating: dataset5/E/y/depth_24_0350.png
#   inflating: dataset5/E/y/depth_24_0351.png
#   inflating: dataset5/E/y/depth_24_0352.png
#   inflating: dataset5/E/y/depth_24_0353.png
#   inflating: dataset5/E/y/depth_24_0354.png
#   inflating: dataset5/E/y/depth_24_0355.png
#   inflating: dataset5/E/y/depth_24_0356.png
#   inflating: dataset5/E/y/depth_24_0357.png
#   inflating: dataset5/E/y/depth_24_0358.png
#   inflating: dataset5/E/y/depth_24_0359.png
#   inflating: dataset5/E/y/depth_24_0360.png
#   inflating: dataset5/E/y/depth_24_0361.png
#   inflating: dataset5/E/y/depth_24_0362.png
#   inflating: dataset5/E/y/depth_24_0363.png
#   inflating: dataset5/E/y/depth_24_0364.png
#   inflating: dataset5/E/y/depth_24_0365.png
#   inflating: dataset5/E/y/depth_24_0366.png
#   inflating: dataset5/E/y/depth_24_0367.png
#   inflating: dataset5/E/y/depth_24_0368.png
#   inflating: dataset5/E/y/depth_24_0369.png
#   inflating: dataset5/E/y/depth_24_0370.png
#   inflating: dataset5/E/y/depth_24_0371.png
#   inflating: dataset5/E/y/depth_24_0372.png
#   inflating: dataset5/E/y/depth_24_0373.png
#   inflating: dataset5/E/y/depth_24_0374.png
#   inflating: dataset5/E/y/depth_24_0375.png
#   inflating: dataset5/E/y/depth_24_0376.png
#   inflating: dataset5/E/y/depth_24_0377.png
#   inflating: dataset5/E/y/depth_24_0378.png
#   inflating: dataset5/E/y/depth_24_0379.png
#   inflating: dataset5/E/y/depth_24_0380.png
#   inflating: dataset5/E/y/depth_24_0381.png
#   inflating: dataset5/E/y/depth_24_0382.png
#   inflating: dataset5/E/y/depth_24_0383.png
#   inflating: dataset5/E/y/depth_24_0384.png
#   inflating: dataset5/E/y/depth_24_0385.png
#   inflating: dataset5/E/y/depth_24_0386.png
#   inflating: dataset5/E/y/depth_24_0387.png
#   inflating: dataset5/E/y/depth_24_0388.png
#   inflating: dataset5/E/y/depth_24_0389.png
#   inflating: dataset5/E/y/depth_24_0390.png
#   inflating: dataset5/E/y/depth_24_0391.png
#   inflating: dataset5/E/y/depth_24_0392.png
#   inflating: dataset5/E/y/depth_24_0393.png
#   inflating: dataset5/E/y/depth_24_0394.png
#   inflating: dataset5/E/y/depth_24_0395.png
#   inflating: dataset5/E/y/depth_24_0396.png
#   inflating: dataset5/E/y/depth_24_0397.png
#   inflating: dataset5/E/y/depth_24_0398.png
#   inflating: dataset5/E/y/depth_24_0399.png
#   inflating: dataset5/E/y/depth_24_0400.png
#   inflating: dataset5/E/y/depth_24_0401.png
#   inflating: dataset5/E/y/depth_24_0402.png
#   inflating: dataset5/E/y/depth_24_0403.png
#   inflating: dataset5/E/y/depth_24_0404.png
#   inflating: dataset5/E/y/depth_24_0405.png
#   inflating: dataset5/E/y/depth_24_0406.png
#   inflating: dataset5/E/y/depth_24_0407.png
#   inflating: dataset5/E/y/depth_24_0408.png
#   inflating: dataset5/E/y/depth_24_0409.png
#   inflating: dataset5/E/y/depth_24_0410.png
#   inflating: dataset5/E/y/depth_24_0411.png
#   inflating: dataset5/E/y/depth_24_0412.png
#   inflating: dataset5/E/y/depth_24_0413.png
#   inflating: dataset5/E/y/depth_24_0414.png
#   inflating: dataset5/E/y/depth_24_0415.png
#   inflating: dataset5/E/y/depth_24_0416.png
#   inflating: dataset5/E/y/depth_24_0417.png
#   inflating: dataset5/E/y/depth_24_0418.png
#   inflating: dataset5/E/y/depth_24_0419.png
#   inflating: dataset5/E/y/depth_24_0420.png
#   inflating: dataset5/E/y/depth_24_0421.png
#   inflating: dataset5/E/y/depth_24_0422.png
#   inflating: dataset5/E/y/depth_24_0423.png
#   inflating: dataset5/E/y/depth_24_0424.png
#   inflating: dataset5/E/y/depth_24_0425.png
#   inflating: dataset5/E/y/depth_24_0426.png
#   inflating: dataset5/E/y/depth_24_0427.png
#   inflating: dataset5/E/y/depth_24_0428.png
#   inflating: dataset5/E/y/depth_24_0429.png
#   inflating: dataset5/E/y/depth_24_0430.png
#   inflating: dataset5/E/y/depth_24_0431.png
#   inflating: dataset5/E/y/depth_24_0432.png
#   inflating: dataset5/E/y/depth_24_0433.png
#   inflating: dataset5/E/y/depth_24_0434.png
#   inflating: dataset5/E/y/depth_24_0435.png
#   inflating: dataset5/E/y/depth_24_0436.png
#   inflating: dataset5/E/y/depth_24_0437.png
#   inflating: dataset5/E/y/depth_24_0438.png
#   inflating: dataset5/E/y/depth_24_0439.png
#   inflating: dataset5/E/y/depth_24_0440.png
#   inflating: dataset5/E/y/depth_24_0441.png
#   inflating: dataset5/E/y/depth_24_0442.png
#   inflating: dataset5/E/y/depth_24_0443.png
#   inflating: dataset5/E/y/depth_24_0444.png
#   inflating: dataset5/E/y/depth_24_0445.png
#   inflating: dataset5/E/y/depth_24_0446.png
#   inflating: dataset5/E/y/depth_24_0447.png
#   inflating: dataset5/E/y/depth_24_0448.png
#   inflating: dataset5/E/y/depth_24_0449.png
#   inflating: dataset5/E/y/depth_24_0450.png
#   inflating: dataset5/E/y/depth_24_0451.png
#   inflating: dataset5/E/y/depth_24_0452.png
#   inflating: dataset5/E/y/depth_24_0453.png
#   inflating: dataset5/E/y/depth_24_0454.png
#   inflating: dataset5/E/y/depth_24_0455.png
#   inflating: dataset5/E/y/depth_24_0456.png
#   inflating: dataset5/E/y/depth_24_0457.png
#   inflating: dataset5/E/y/depth_24_0458.png
#   inflating: dataset5/E/y/depth_24_0459.png
#   inflating: dataset5/E/y/depth_24_0460.png
#   inflating: dataset5/E/y/depth_24_0461.png
#   inflating: dataset5/E/y/depth_24_0462.png
#   inflating: dataset5/E/y/depth_24_0463.png
#   inflating: dataset5/E/y/depth_24_0464.png
#   inflating: dataset5/E/y/depth_24_0465.png
#   inflating: dataset5/E/y/depth_24_0466.png
#   inflating: dataset5/E/y/depth_24_0467.png
#   inflating: dataset5/E/y/depth_24_0468.png
#   inflating: dataset5/E/y/depth_24_0469.png
#   inflating: dataset5/E/y/depth_24_0470.png
#   inflating: dataset5/E/y/depth_24_0471.png
#   inflating: dataset5/E/y/depth_24_0472.png
#   inflating: dataset5/E/y/depth_24_0473.png
#   inflating: dataset5/E/y/depth_24_0474.png
#   inflating: dataset5/E/y/depth_24_0475.png
#   inflating: dataset5/E/y/depth_24_0476.png
#   inflating: dataset5/E/y/depth_24_0477.png
#   inflating: dataset5/E/y/depth_24_0478.png
#   inflating: dataset5/E/y/depth_24_0479.png
#   inflating: dataset5/E/y/depth_24_0480.png
#   inflating: dataset5/E/y/depth_24_0481.png
#   inflating: dataset5/E/y/depth_24_0482.png
#   inflating: dataset5/E/y/depth_24_0483.png
#   inflating: dataset5/E/y/depth_24_0484.png
#   inflating: dataset5/E/y/depth_24_0485.png
#   inflating: dataset5/E/y/depth_24_0486.png
#   inflating: dataset5/E/y/depth_24_0487.png
#   inflating: dataset5/E/y/depth_24_0488.png
#   inflating: dataset5/E/y/depth_24_0489.png
#   inflating: dataset5/E/y/depth_24_0490.png
#   inflating: dataset5/E/y/depth_24_0491.png
#   inflating: dataset5/E/y/depth_24_0492.png
#   inflating: dataset5/E/y/depth_24_0493.png
#   inflating: dataset5/E/y/depth_24_0494.png
#   inflating: dataset5/E/y/depth_24_0495.png
#   inflating: dataset5/E/y/depth_24_0496.png
#   inflating: dataset5/E/y/depth_24_0497.png
#   inflating: dataset5/E/y/depth_24_0498.png
#   inflating: dataset5/E/y/depth_24_0499.png
#   inflating: dataset5/E/y/depth_24_0500.png
#   inflating: dataset5/E/y/depth_24_0501.png
#   inflating: dataset5/E/y/depth_24_0502.png
#   inflating: dataset5/E/y/depth_24_0503.png
#   inflating: dataset5/E/y/depth_24_0504.png
#   inflating: dataset5/E/y/depth_24_0505.png
#   inflating: dataset5/E/y/depth_24_0506.png
#   inflating: dataset5/E/y/depth_24_0507.png
#   inflating: dataset5/E/y/depth_24_0508.png
#   inflating: dataset5/E/y/depth_24_0509.png
#   inflating: dataset5/E/y/depth_24_0510.png
#   inflating: dataset5/E/y/depth_24_0511.png
#   inflating: dataset5/E/y/depth_24_0512.png
#   inflating: dataset5/E/y/depth_24_0513.png
#   inflating: dataset5/E/y/depth_24_0514.png
#   inflating: dataset5/E/y/depth_24_0515.png
#   inflating: dataset5/E/y/depth_24_0516.png
#   inflating: dataset5/E/y/depth_24_0517.png
#   inflating: dataset5/E/y/depth_24_0518.png
#   inflating: dataset5/E/y/depth_24_0519.png
#   inflating: dataset5/E/y/depth_24_0520.png
#   inflating: dataset5/E/y/depth_24_0521.png
#   inflating: dataset5/E/y/depth_24_0522.png

# %% [markdown]
# ### Transforming Dataset

# %%
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

dataset = ImageFolder(data_dir, transform = transform)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_sample(img, label):
    print("Label:", dataset.classes[label], "(Class No: "+ str(label) + ")")
    plt.imshow(img.permute(1, 2, 0))

print("Number of classes: ",len(dataset.classes))
print("Number of images: ",len(dataset.samples))
# Out:
# Number of classes:  24
# Number of images:  27820

# %%
# Splitting dataset into train, validation and test

train_size = int(0.7 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = int(0.1 * len(dataset))
extra_size = int(0 * len(dataset))
train_ds, val_ds, test_ds, extra_ds = random_split(dataset, [train_size, val_size, test_size, extra_size])
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (19474, 5564, 2782)

# %%
from torch.utils.data import DataLoader
batch_size = 64

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
test_dl = DataLoader(test_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
val_dl = DataLoader(val_ds, batch_size, shuffle = True, num_workers = 4, pin_memory = True)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
from torchvision.utils import make_grid

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(12, 6))
        ax.set_xticks([])
        ax.set_yticks([])
        ax.imshow(make_grid(images, nrow = 16).permute(1, 2, 0))
        break

# show_batch(train_dl)

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

class ImageClassificationBase(nn.Module):
    def training_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'train_loss': loss.detach(), 'train_acc': acc}

    def testing_step(self, batch):
        images, labels = batch 
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'test_loss': loss.detach(), 'test_acc': acc}
    
    def validation_step(self, batch):
        images, labels = batch 
        out = self(images)                    # Generate predictions
        loss = F.cross_entropy(out, labels)   # Calculate loss
        acc = accuracy(out, labels)           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}

    def training_epoch_end(self, outputs):
        batch_losses = [x['train_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['train_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'train_loss': epoch_loss.item(), 'train_acc': epoch_acc.item()}
       
    def testing_epoch_end(self, outputs):
        batch_losses = [x['test_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['test_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'test_loss': epoch_loss.item(), 'test_acc': epoch_acc.item()}
       
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch {}: train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f}, train_acc: {:.4f}, test_acc: {:.4f}, val_acc: {:.4f}".format(
            epoch+1, result['train_loss'], result['test_loss'], result['val_loss'], result['train_acc'], result['test_acc'], result['val_acc']))

# %%
from torchvision.models import resnet18, ResNet18_Weights

model = resnet18(num_classes=24)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
train_dl = DeviceDataLoader(train_dl, device)
test_dl = DeviceDataLoader(test_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
to_device(model, device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=24, bias=True)
# )

# %%
from torch.nn.modules import loss
from torch.optim.adam import Adam
num_epochs = 10
lr =  0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
loss_function = nn.CrossEntropyLoss();

# %%
from torch.autograd import Variable
#Model Training and saving best Model
best_accuracy = 0.0
train_acc_list = []
test_acc_list = []
val_acc_list = []
train_loss_list = []
test_loss_list = []
val_loss_list = []
epo = []
t1 = time.time()
for epoch in range(num_epochs):
  #evaluation and training on training dataset
  model.train()
  train_acc = 0.0
  train_loss = 0.0
  t2 = time.time()

  for i, (images, labels) in enumerate(train_dl):
    if(torch.cuda.is_available()):
      images = Variable(images.cuda())
      labels = Variable(labels.cuda())
      
    optimizer.zero_grad()
    outputs = model(images)
    loss = loss_function(outputs, labels)
    loss.backward()
    optimizer.step()
    # scheduler.step()

    train_loss += loss.cpu().data*images.size(0)
    _,prediction=torch.max(outputs.data,1)

    train_acc += int(torch.sum(prediction==labels.data))

  train_acc = (train_acc / train_size)*100
  train_loss = train_loss / train_size
      
  #Evaluation on testing dataset
  model.eval()

  val_acc = 0.0
  correct2 = 0
  total2 = 0
  val_loss = 0.0

  for i, (images, labels) in enumerate(val_dl):
    if(torch.cuda.is_available()):
      images = Variable(images.cuda())
      labels = Variable(labels.cuda())

    outputs = model(images)
    val_loss += loss.cpu().data*images.size(0)
    _,prediction=torch.max(outputs.data,1)
    val_acc += int(torch.sum(prediction==labels.data))
    total2 += labels.size(0)
    correct2 += (prediction == labels).sum().item()

  val_loss = val_loss / val_size
  val_acc = (val_acc / val_size)*100
  print('Epoch[{}]({:.0f} sec)  Train Loss: {:.4f}, Train Accuracy:  {:.4f}, Val Loss: {:.4f}, Val Accuracy: {:.4f}\n'.format(epoch+1,time.time()-t2,train_loss,train_acc,val_loss,val_acc))
  train_acc_list.append(train_acc)
  # test_acc_list.append(test_acc)
  val_acc_list.append(val_acc)
  train_loss_list.append(train_loss)
  # test_loss_list.append(test_loss)
  val_loss_list.append(val_loss)
  epo.append(epoch+1)

  if(val_acc>best_accuracy):
    torch.save(model.state_dict(), 'best_checkpoint.model')
    best_accuracy = val_acc

torch.save(model.state_dict(), 'Resnet18-dataset3-batch_size'+str(batch_size)+ 'lr-' + str(lr)+'epochs-'+str(num_epochs)+'.pth')

print("######## Training Finished in {:.0f} seconds ###########".format(time.time()-t1))
# print('Test Accuracy of the model on the {} test images: {} %'.format(total1, (correct1 / total1) * 100))
# print('Test Accuracy of the model on the {} validation images: {} %'.format(total2, (correct2 / total2) * 100))
# Out:
# Epoch[1](99 sec)  Train Loss: 1.2400, Train Accuracy:  62.3447, Val Loss: 0.7930, Val Accuracy: 81.2185
#
# Epoch[2](85 sec)  Train Loss: 0.4908, Train Accuracy:  84.7386, Val Loss: 0.3267, Val Accuracy: 64.6118
#
# Epoch[3](88 sec)  Train Loss: 0.3313, Train Accuracy:  89.4475, Val Loss: 0.1415, Val Accuracy: 52.6779
#
# Epoch[4](84 sec)  Train Loss: 0.2600, Train Accuracy:  91.6453, Val Loss: 0.3798, Val Accuracy: 54.1517
#
# Epoch[5](85 sec)  Train Loss: 0.2100, Train Accuracy:  92.9958, Val Loss: 0.1650, Val Accuracy: 55.3559
#
# Epoch[6](86 sec)  Train Loss: 0.1692, Train Accuracy:  94.3052, Val Loss: 0.1514, Val Accuracy: 92.5953
#
# Epoch[7](84 sec)  Train Loss: 0.1378, Train Accuracy:  95.3322, Val Loss: 0.2770, Val Accuracy: 90.0971
#
# Epoch[8](86 sec)  Train Loss: 0.1433, Train Accuracy:  95.0652, Val Loss: 0.2115, Val Accuracy: 92.7031
#
# Epoch[9](91 sec)  Train Loss: 0.1170, Train Accuracy:  95.8560, Val Loss: 0.1132, Val Accuracy: 90.3846
#
# Epoch[10](89 sec)  Train Loss: 0.0970, Train Accuracy:  96.4465, Val Loss: 0.0309, Val Accuracy: 93.4939
#
# ######## Training Finished in 877 seconds ###########

# %%
plt.rcParams["figure.figsize"] = (5,3)
fig, ax = plt.subplots()
plt.plot(epo, train_acc_list, label='Train Acc')
plt.plot(epo, val_acc_list, label='Val Acc')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

fig, ax = plt.subplots()
plt.plot(epo, train_loss_list, label='Train Loss')
plt.plot(epo, val_loss_list, label='Val Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Accuracy & Loss vs. No. of epochs');

plt.grid()
plt.show()

# %% [markdown]
# # New Section

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
from torchvision.models import resnet18

test_model = resnet18(num_classes=24)
test_model.load_state_dict(torch.load('/content/Resnet18-dataset3-batch_size64lr-0.001epochs-10.pth'))
test_model.eval()

to_device(test_model, device)

# print(test_model)

test_preds = []
test_labels = []

for data in test_dl:
    images, labels = data[0].to(device), data[1].to(device)
    output = test_model(images)
    output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
    test_preds.extend(output) 
    labels = labels.data.cpu().numpy()
    test_labels.extend(labels) 

accuracy = accuracy_score(test_preds, test_labels)*100
print('Test Accuracy: {}'.format(accuracy))

target_names = list(dataset.class_to_idx.keys())

fig, ax = plt.subplots(figsize=(10,10))
cm = confusion_matrix(test_labels, test_preds)
sns.heatmap(cm, annot=True, cmap='Oranges', fmt='g', xticklabels=target_names, yticklabels=target_names, ax=ax)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

print(classification_report(test_labels, test_preds, target_names=target_names))
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Test Accuracy: 93.13443565780014
#               precision    recall  f1-score   support
#
#            a       0.99      0.93      0.96        91
#            b       0.96      0.99      0.98       123
#            c       1.00      0.93      0.96       124
#            d       0.98      0.97      0.97       100
#            e       1.00      0.80      0.89       123
#            f       0.99      0.95      0.97       110
#            g       0.92      0.94      0.93       115
#            h       0.91      0.93      0.92       108
#            i       0.92      0.96      0.94       121
#            k       0.92      0.95      0.93       151
#            l       0.99      1.00      1.00       110
#            m       0.75      0.86      0.80       110
#            n       0.91      0.81      0.85       108
#            o       0.98      0.85      0.91       117
#            p       1.00      0.96      0.98       133
#            q       1.00      1.00      1.00       115
#            r       0.99      0.93      0.96       115
#            s       0.72      0.97      0.83       138
#            t       0.88      0.88      0.88       104
#            u       0.95      0.90      0.92       107
#            v       0.97      0.92      0.94       134
#            w       0.98      0.95      0.97       110
#            x       0.88      0.95      0.92       120
#            y       0.95      1.00      0.97        95
#
#     accuracy                           0.93      2782
#    macro avg       0.94      0.93      0.93      2782
# weighted avg       0.94      0.93      0.93      2782

# %%
import torch
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

model.to('cuda')

model = torch.nn.Sequential(*(list(model.children())[:-1]))

model.eval()

features = []
labels = []
for images, target in train_dl:
    images = images.to('cuda')
    with torch.no_grad():
        output = model(images)
        features.append(output.squeeze().cpu().numpy())
        labels.append(target.cpu().numpy())

features = np.concatenate(features, axis=0)
labels = np.concatenate(labels, axis=0)

tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=2000)
tsne_features = tsne.fit_transform(features)

target_names = list(dataset.class_to_idx.keys())

cmap = plt.cm.get_cmap('tab10', len(target_names)-1)

u = False

plt.figure(figsize=(10, 10))
for i, target_name in enumerate(target_names):
    if target_name != "unknown":
        indices = labels == i
        plt.scatter(tsne_features[indices, 0], tsne_features[indices, 1], label=target_name, c=cmap(i))
plt.scatter(tsne_features[u, 0], tsne_features[u, 1], label="unknown", c="k")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 19474 samples in 0.004s...
# [t-SNE] Computed neighbors for 19474 samples in 16.927s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 19474
# [t-SNE] Computed conditional probabilities for sample 2000 / 19474
# [t-SNE] Computed conditional probabilities for sample 3000 / 19474
# [t-SNE] Computed conditional probabilities for sample 4000 / 19474
# [t-SNE] Computed conditional probabilities for sample 5000 / 19474
# [t-SNE] Computed conditional probabilities for sample 6000 / 19474
# [t-SNE] Computed conditional probabilities for sample 7000 / 19474
# [t-SNE] Computed conditional probabilities for sample 8000 / 19474
# [t-SNE] Computed conditional probabilities for sample 9000 / 19474
# [t-SNE] Computed conditional probabilities for sample 10000 / 19474
# [t-SNE] Computed conditional probabilities for sample 11000 / 19474
# [t-SNE] Computed conditional probabilities for sample 12000 / 19474
# [t-SNE] Computed conditional probabilities for sample 13000 / 19474
# [t-SNE] Computed conditional probabilities for sample 14000 / 19474
# [t-SNE] Computed conditional probabilities for sample 15000 / 19474
# [t-SNE] Computed conditional probabilities for sample 16000 / 19474
# [t-SNE] Computed conditional probabilities for sample 17000 / 19474
# [t-SNE] Computed conditional probabilities for sample 18000 / 19474
# [t-SNE] Computed conditional probabilities for sample 19000 / 19474
# [t-SNE] Computed conditional probabilities for sample 19474 / 19474
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.429581
# [t-SNE] KL divergence after 2000 iterations: 0.985736
# <ipython-input-18-f1110ce59b62>:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(target_names)-1)
# <ipython-input-18-f1110ce59b62>:37: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(tsne_features[indices, 0], tsne_features[indices, 1], label=target_name, c=cmap(i))
